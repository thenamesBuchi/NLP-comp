# %% [markdown]
# <a href="https://colab.research.google.com/github/thenamesBuchi/NLP-comp/blob/main/TF_IDF_comp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Download the SpaCy model if not already present
# !python -m spacy download en_core_web_md

# Load SpaCy
nlp = spacy.load("en_core_web_md")

resume = "I am a student skilled in Python and SQL databases"
job_desc = "Looking for a developer with experience in Python and PostgreSQL"

# 1. TF-IDF
tfidf_vec = TfidfVectorizer()
tfidf_matrix = tfidf_vec.fit_transform([resume, job_desc])
tfidf_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]

# 2. SpaCy (Word2Vec)
doc1 = nlp(resume)
doc2 = nlp(job_desc)
spacy_sim = doc1.similarity(doc2)

print(f"TF-IDF Similarity: {tfidf_sim:.4f}")
print(f"SpaCy (Word2Vec) Similarity: {spacy_sim:.4f}")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 21.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# TF-IDF Similarity: 0.2169
# SpaCy (Word2Vec) Similarity: 0.8923

# %%
import pandas as pd
df = pd.read_csv('/content/resume_dataset_1200.csv') # Paste the copied path here
print(df.head())
# Out:
#                Name  Age      Gender Education_Level           Field_of_Study  \
# 0      Akash Pillai   30  Non-Binary        Master's            Cybersecurity
# 1  Charlotte Taylor   27  Non-Binary      Bachelor's  Electronics Engineering
# 2        James Zhou   45        Male      Bachelor's         Computer Science
# 3     Amelia Thomas   28        Male        Master's   Information Technology
# 4       Amanda Jain   42  Non-Binary        Master's  Electronics Engineering
#
#                                  Degrees              Institute_Name  \
# 0              Master's in Cybersecurity  University of Pennsylvania
# 1  Bachelor's in Electronics Engineering             Pune University
# 2         Bachelor's in Computer Science            Amity University
# 3     Master's in Information Technology  University of Pennsylvania
# 4    Master's in Electronics Engineering       University of Toronto
#
#    Graduation_Year  Experience_Years       Current_Job_Title  \
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import spacy
from sentence_transformers import SentenceTransformer, util

# 1. Load Data
df = pd.read_csv('/content/resume_dataset_1200.csv')

# 2. Select a Sample (Let's use Akash Pillai at Index 0)
resume_text = df.iloc[0]['Skills']
job_desc_1 = df.iloc[0]['Target_Job_Description']
job_desc_2 = df.iloc[1]['Target_Job_Description']

# --- MODEL 1: TF-IDF ---
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([resume_text, job_desc_1, job_desc_2])
tfidf_scores = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])
print(f"TF-IDF Scores: Job 1: {tfidf_scores[0][0]:.4f}, Job 2: {tfidf_scores[0][1]:.4f}")

# --- MODEL 2: SpaCy (Word2Vec) ---
#
nlp = spacy.load("en_core_web_md")
doc_res = nlp(resume_text)
score_spacy_1 = doc_res.similarity(nlp(job_desc_1))
score_spacy_2 = doc_res.similarity(nlp(job_desc_2))
print(f"SpaCy Scores: Job 1: {score_spacy_1:.4f}, Job 2: {score_spacy_2:.4f}")

# --- MODEL 3: Sentence-BERT ---
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')
emb_res = sbert_model.encode(resume_text)
emb_j1 = sbert_model.encode(job_desc_1)
emb_j2 = sbert_model.encode(job_desc_2)
score_sbert_1 = util.cos_sim(emb_res, emb_j1)
score_sbert_2 = util.cos_sim(emb_res, emb_j2)
print(f"SBERT Scores: Job 1: {score_sbert_1.item():.4f}, Job 2: {score_sbert_2.item():.4f}")
# Out:
# TF-IDF Scores: Job 1: 0.0000, Job 2: 0.0000
# SpaCy Scores: Job 1: 0.7895, Job 2: 0.7646
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import spacy
from sentence_transformers import SentenceTransformer, util

# 1. Load Data
df = pd.read_csv('/content/resume_dataset_1200.csv')

# 2. Select a Sample (Let's use Akash Pillai at Index 0)
resume_text = df.iloc[1]['Skills']
job_desc_1 = df.iloc[1]['Target_Job_Description']
job_desc_2 = df.iloc[2]['Target_Job_Description']

# --- MODEL 1: TF-IDF ---
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([resume_text, job_desc_1, job_desc_2])
tfidf_scores = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])
print(f"TF-IDF Scores: Job 1: {tfidf_scores[0][0]:.4f}, Job 2: {tfidf_scores[0][1]:.4f}")

# --- MODEL 2: SpaCy (Word2Vec) ---
#
nlp = spacy.load("en_core_web_md")
doc_res = nlp(resume_text)
score_spacy_1 = doc_res.similarity(nlp(job_desc_1))
score_spacy_2 = doc_res.similarity(nlp(job_desc_2))
print(f"SpaCy Scores: Job 1: {score_spacy_1:.4f}, Job 2: {score_spacy_2:.4f}")

# --- MODEL 3: Sentence-BERT ---
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')
emb_res = sbert_model.encode(resume_text)
emb_j1 = sbert_model.encode(job_desc_1)
emb_j2 = sbert_model.encode(job_desc_2)
score_sbert_1 = util.cos_sim(emb_res, emb_j1)
score_sbert_2 = util.cos_sim(emb_res, emb_j2)
print(f"SBERT Scores: Job 1: {score_sbert_1.item():.4f}, Job 2: {score_sbert_2.item():.4f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1281/1269441294.py in <cell line: 0>()
#       6
#       7 # 1. Load Data
# ----> 8 df = pd.read_csv('/content/resume_dataset_1200.csv')
#       9
#      10 # 2. Select a Sample (Let's use Akash Pillai at Index 0)
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import spacy
from sentence_transformers import SentenceTransformer, util

# Ensure the SpaCy model is downloaded
# !python -m spacy download en_core_web_md --quiet

# 1. Load Data
df = pd.read_csv('/content/resume_dataset_1200.csv')

# 2. Select a Sample (Let's use Akash Pillai at Index 0)
resume_text = df.iloc[2]['Skills']
job_desc_1 = df.iloc[1]['Target_Job_Description']
job_desc_2 = df.iloc[2]['Target_Job_Description']

# --- MODEL 1: TF-IDF ---
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([resume_text, job_desc_1, job_desc_2])
tfidf_scores = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])
print(f"TF-IDF Scores: Job 1: {tfidf_scores[0][0]:.4f}, Job 2: {tfidf_scores[0][1]:.4f}")

# --- MODEL 2: SpaCy (Word2Vec) ---
#
nlp = spacy.load("en_core_web_md")
doc_res = nlp(resume_text)
score_spacy_1 = doc_res.similarity(nlp(job_desc_1))
score_spacy_2 = doc_res.similarity(nlp(job_desc_2))
print(f"SpaCy Scores: Job 1: {score_spacy_1:.4f}, Job 2: {score_spacy_2:.4f}")

# --- MODEL 3: Sentence-BERT ---
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')
emb_res = sbert_model.encode(resume_text)
emb_j1 = sbert_model.encode(job_desc_1)
emb_j2 = sbert_model.encode(job_desc_2)
score_sbert_1 = util.cos_sim(emb_res, emb_j1)
score_sbert_2 = util.cos_sim(emb_res, emb_j2)
print(f"SBERT Scores: Job 1: {score_sbert_1.item():.4f}, Job 2: {score_sbert_2.item():.4f}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 39.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# TF-IDF Scores: Job 1: 0.0000, Job 2: 0.0000
# SpaCy Scores: Job 1: 0.7961, Job 2: 0.7889
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...
